# %%
import numpy as np
import pandas as pd
import seaborn as sns

import pandas as pd
import seaborn as sns
sns.set_palette("muted")
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

pd.options.display.max_rows = 200
pd.options.display.max_columns = 200

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
df = pd.read_csv('movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724811 entries, 0 to 724810
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    724811 non-null  int64
#  1   title                 724807 non-null  object
#  2   genres                512760 non-null  object
#  3   original_language     724811 non-null  object
#  4   overview              605623 non-null  object
#  5   popularity            724811 non-null  float64
#  6   production_companies  337563 non-null  object
#  7   release_date          671529 non-null  object
#  8   budget                724811 non-null  float64
#  9   revenue               724811 non-null  float64
#  10  runtime               689949 non-null  float64
#  11  status                724811 non-null  object
#  12  tagline               108113 non-null  object
#  13  vote_average          724811 non-null  float64
# ...

# %%
x=df
x
# Out:
#             id                           title  \
# 0       505642  Black Panther: Wakanda Forever
# 1       315162    Puss in Boots: The Last Wish
# 2       646389                           Plane
# 3       956101               The Eighth Clause
# 4       536554                           M3GAN
# ...        ...                             ...
# 724806  757792                  Cows Come Home
# 724807  839703                       Sabotage5
# 724808  912141                    Romania 2021
# 724809  855655                    Eliza Smiles
# 724810  968161                   Gising Sining
#
#                                            genres original_language  \
# 0                Action-Adventure-Science Fiction                en
# 1       Animation-Adventure-Comedy-Family-Fantasy                en
# 2                       Action-Adventure-Thriller                en
# 3                                        Thriller                la
# ...

# %%
x['revenue'] = df['revenue'].astype(float)
x['budget'] = df['budget'].astype(float)
x = x.replace(0, np.nan) # np.nan is a special value representing missing values

# %%
x.head()
# Out:
#        id                           title  \
# 0  505642  Black Panther: Wakanda Forever
# 1  315162    Puss in Boots: The Last Wish
# 2  646389                           Plane
# 3  956101               The Eighth Clause
# 4  536554                           M3GAN
#
#                                       genres original_language  \
# 0           Action-Adventure-Science Fiction                en
# 1  Animation-Adventure-Comedy-Family-Fantasy                en
# 2                  Action-Adventure-Thriller                en
# 3                                   Thriller                la
# 4              Science Fiction-Horror-Comedy                en
#
#                                             overview  popularity  \
# 0  Queen Ramonda Shuri M’Baku Okoye and the Dora ...    4378.531
# 1  Puss in Boots discovers that his passion for a...    3204.321
# 2  After a heroic job of successfully landing his...    3115.286
# ...

# %%
x = x.dropna(subset=['release_date'])
x = x.dropna(subset=['genres'])
x = x.dropna(subset=['popularity'])
x = x.dropna(subset=['production_companies'])
x = x.dropna(subset=['budget'])
x = x.dropna(subset=['revenue'])
x = x.dropna(subset=['runtime'])
x = x.dropna(subset=['runtime'])
x = x.dropna(subset=['vote_average'])
x = x.dropna(subset=['vote_count'])
x = x.dropna(subset=['credits'])

x
# Out:
#             id                           title  \
# 0       505642  Black Panther: Wakanda Forever
# 1       315162    Puss in Boots: The Last Wish
# 2       646389                           Plane
# 4       536554                           M3GAN
# 8        76600        Avatar: The Way of Water
# ...        ...                             ...
# 708913  823471                         Beached
# 709103  817989                       The Vigil
# 716447  838099                      The Plague
# 719989  854916                         Rejects
# 721924  853631                       A Way Out
#
#                                            genres original_language  \
# 0                Action-Adventure-Science Fiction                en
# 1       Animation-Adventure-Comedy-Family-Fantasy                en
# 2                       Action-Adventure-Thriller                en
# 4                   Science Fiction-Horror-Comedy                en
# ...

# %%
x.reset_index(drop=True, inplace=True)
x = x.drop(['recommendations', 'backdrop_path','poster_path','tagline','keywords'], axis=1)

# %%
#x=x1
x.to_csv('myFilmdata.csv', index=False)

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\mrkid\CapstoneProject

# %%
x['budget']
# Out:
# 0        250000000.0
# 1         90000000.0
# 2         25000000.0
# 3         12000000.0
# 4        460000000.0
#             ...
# 11065       500000.0
# 11066          500.0
# 11067            1.0
# 11068           10.0
# 11069           10.0
# Name: budget, Length: 11070, dtype: float64

# %%
x.loc[:, 'budget']= x['budget'] / 1000000
x['budget']
# Out:
# 0        250.000000
# 1         90.000000
# 2         25.000000
# 3         12.000000
# 4        460.000000
#             ...
# 11065      0.500000
# 11066      0.000500
# 11067      0.000001
# 11068      0.000010
# 11069      0.000010
# Name: budget, Length: 11070, dtype: float64

# %%
x.loc[:, 'revenue'] = x['revenue'] / 1000000
x['revenue']
# Out:
# 0         855.099029
# 1         423.000000
# 2          46.000000
# 3         167.643991
# 4        2243.275991
#             ...
# 11065      50.000000
# 11066       0.000500
# 11067       0.000720
# 11068       0.000500
# 11069       0.000005
# Name: revenue, Length: 11070, dtype: float64

# %%
plt.figure(figsize=(10, 10))

# %%
sns.regplot(x = 'budget', y = 'revenue', data = x1, scatter_kws={'alpha':0.5})
plt.xlim(0, 600)
plt.ylim(0, 2500)
plt.title('Budget vs Revenue')          # Set title.
plt.xlabel("Budget ")       # Set x-axis label.
plt.ylabel('Revenue')    # Set y-axis label.
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>
# (0.0, 600.0)
# (0.0, 2500.0)
# Text(0.5, 1.0, 'Budget vs Revenue')
# Text(0.5, 0, 'Budget ')
# Text(0, 0.5, 'Revenue')

# %%
sns.jointplot(x = 'budget', y = 'revenue', data = x, xlim=(0, 1000), ylim=(0, 2500),alpha = 0.5)
